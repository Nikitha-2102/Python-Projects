# %%
def add(num1,num2):
  return num1+num2
def sub(num1,num2):
  return num1-num2
def multiply(num1,num2):
  return num1*num2
def divide(num1,num2):
  return num1/num

def avg(num1,num2):
  return (num1+num2)/2

print("Please select an operation:\n "\
"1.Addition\n" \
 "2.Subtraction\n" \
 "3.Multiplication\n" \
 "4.Division\n" \
 "5.Average\n")

select= int(input("Select a operation1,2,3,4,5 from above operation"))

n1=int(input("Enter the First number: "))
n2=int(input("Enter the second number: "))

if select == 1:
  print(n1,"+",n2,"=",add(n1,n2))
elif select ==2:
  print(n1,"-",n2,"=",sub(n1,n2))
elif select ==3:
  print(n1,"x",n2,"=",multiply(n1,n2))
elif select ==4:
  print(n1,"/",n2,"=",divide(n1,n2))
elif select ==5:
  print("(",n1,"+",n2,")","/","2","=",avg(n1,n2))
else:
  print("Invalid operation")
# Out:
# Please select an operation:
#  1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Average
#
# Select a operation1,2,3,4,5 from above operation1
# Enter the First number: 3
# Enter the second number: 6
# 3 + 6 = 9
